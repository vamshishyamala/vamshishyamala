# %%
import pandas as pd
d=pd.read_csv('/content/drive/MyDrive/Share who_life_exp1.csv')
print(d)
# Out:
#                                country country_code           region  year  \
# 0                               Angola          AGO           Africa  2000
# 1                               Angola          AGO           Africa  2001
# 2                               Angola          AGO           Africa  2002
# 3                               Angola          AGO           Africa  2003
# 4                               Angola          AGO           Africa  2004
# ...                                ...          ...              ...   ...
# 3106  Lao People's Democratic Republic          LAO  Western Pacific  2012
# 3107  Lao People's Democratic Republic          LAO  Western Pacific  2013
# 3108  Lao People's Democratic Republic          LAO  Western Pacific  2014
# 3109  Lao People's Democratic Republic          LAO  Western Pacific  2015
# 3110  Lao People's Democratic Republic          LAO  Western Pacific  2016
#
#       life_expect  life_exp60  adult_mortality  infant_mort  age1-4mort  \
# 0        47.33730    14.73400         383.5583     0.137985    0.025695
# 1        48.19789    14.95963         372.3876     0.133675    0.024500
# 2        49.42569    15.20010         354.5147     0.128320    0.023260
# 3        50.50266    15.39144         343.2169     0.122040    0.021925
# 4        51.52863    15.56860         333.8711     0.115700    0.020545
# ...           ...         ...              ...          ...         ...
# 3106     64.49448    16.57977         209.2666     0.055840    0.004845
# 3107     64.79716    16.64219         205.1459     0.055350    0.004600
# 3108     65.10757    16.70787         200.8204     0.054585    0.004405
# 3109     65.45008    16.77074         196.6613     0.053465    0.004160
# 3110     65.79089    16.83024         192.7939     0.051895    0.003990
#
#       alcohol  ...  che_gdp    une_pop  une_infant  une_life  une_hiv  \
# 0     1.47439  ...  1.90860  16395.473       122.2    46.522      1.0
# 1     1.94025  ...  4.48352  16945.753       118.9    47.059      1.1
# 2     2.07512  ...  3.32946  17519.417       115.1    47.702      1.2
# 3     2.20275  ...  3.54797  18121.479       110.8    48.440      1.3
# 4     2.41274  ...  3.96720  18758.145       106.2    49.263      1.3
# ...       ...  ...      ...        ...         ...       ...      ...
# 3106  6.29833  ...  2.07638   6444.530        47.5    65.267      0.3
# 3107  6.42186  ...  2.39985   6541.304        45.6    65.717      0.3
# 3108  6.64447  ...  2.29846   6639.756        43.7    66.144      0.3
# 3109  6.83826  ...  2.45366   6741.164        42.0    66.546      0.3
# 3110  7.11148  ...  2.36087   6845.846        40.4    66.924      0.3
#
#       une_gni  une_poverty  une_edu_spend  une_literacy  une_school
# 0        2530         32.3        2.60753       0.00000         0.0
# 1        2630          0.0        0.00000      67.40542         0.0
# 2        3180          0.0        0.00000       0.00000         0.0
# 3        3260          0.0        0.00000       0.00000         0.0
# 4        3560          0.0        0.00000       0.00000         0.0
# ...       ...          ...            ...           ...         ...
# 3106     4570         22.7        1.82147       0.00000         0.0
# 3107     4980          0.0        3.23381       0.00000         0.0
# 3108     5440          0.0        2.93781       0.00000         0.0
# 3109     5810          0.0        0.00000      84.66104         0.0
# 3110     6190          0.0        0.00000       0.00000         0.0
#
# [3111 rows x 32 columns]

# %%
import matplotlib.pyplot as plt
x1=d['country']
y=d['life_expect']
plt.plot(x1,y)

# %%
import matplotlib.pyplot as plt
x2=d['country_code']
y=d['life_expect']
plt.plot(x2,y)

# %%
import matplotlib.pyplot as plt
x3=d['region']
y=d['life_expect']
plt.plot(x3,y)

# %%
import matplotlib.pyplot as plt
x4=d['year']
y=d['life_expect']
plt.plot(x4,y)

# %%
import matplotlib.pyplot as plt
x5=d['life_exp60']
y=d['life_expect']
plt.plot(x5,y)

# %%
import matplotlib.pyplot as plt
x6=d['adult_mortality']
y=d['life_expect']
plt.plot(x6,y)

# %%
import matplotlib.pyplot as plt
x7=d['infant_mort']
y=d['life_expect']
plt.plot(x7,y)

# %%
import matplotlib.pyplot as plt
x8=d['age1-4mort']
y=d['life_expect']
plt.plot(x8,y)

# %%
import matplotlib.pyplot as plt
x9=d['alcohol']
y=d['life_expect']
plt.plot(x9,y)

# %%
import matplotlib.pyplot as plt
x10=d['bmi']
y=d['life_expect']
plt.plot(x10,y)

# %%
import matplotlib.pyplot as plt
x11=d['age5-19thinness']
y=d['life_expect']
plt.plot(x11,y)

# %%
import matplotlib.pyplot as plt
x12=d['age5-19obesity']
y=d['life_expect']
plt.plot(x12,y)

# %%
import matplotlib.pyplot as plt
x13=d['hepatitis']
y=d['life_expect']
plt.plot(x13,y)

# %%
import matplotlib.pyplot as plt
x14=d['measles']
y=d['life_expect']
plt.plot(x14,y)

# %%
import matplotlib.pyplot as plt
x15=d['polio']
y=d['life_expect']
plt.plot(x15,y)

# %%
import matplotlib.pyplot as plt
x16=d['diphtheria']
y=d['life_expect']
plt.plot(x16,y)

# %%
import matplotlib.pyplot as plt
x17=d['basic_water']
y=d['life_expect']
plt.plot(x17,y)

# %%
import matplotlib.pyplot as plt
x18=d['doctors']
y=d['life_expect']
plt.plot(x18,y)

# %%
import matplotlib.pyplot as plt
x19=d['hospitals']
y=d['life_expect']
plt.plot(x19,y)

# %%
import matplotlib.pyplot as plt
x20=d['gni_capita']
y=d['life_expect']
plt.plot(x20,y)

# %%
import matplotlib.pyplot as plt
x21=d['gghe-d']
y=d['life_expect']
plt.plot(x21,y)

# %%
import matplotlib.pyplot as plt
x22=d['che_gdp']
y=d['life_expect']
plt.plot(x22,y)

# %%
import matplotlib.pyplot as plt
x23=d['une_pop']
y=d['life_expect']
plt.plot(x23,y)

# %%
import matplotlib.pyplot as plt
x24=d['une_infant']
y=d['life_expect']
plt.plot(x24,y)

# %%
import matplotlib.pyplot as plt
x25=d['une_life']
y=d['life_expect']
plt.plot(x25,y)

# %%
import matplotlib.pyplot as plt
x26=d['une_hiv']
y=d['life_expect']
plt.plot(x26,y)

# %%
import matplotlib.pyplot as plt
x27=d['une_gni']
y=d['life_expect']
plt.plot(x27,y)

# %%
import matplotlib.pyplot as plt
x28=d['une_poverty']
y=d['life_expect']
plt.plot(x28,y)

# %%
import matplotlib.pyplot as plt
x29=d['une_edu_spend']
y=d['life_expect']
plt.plot(x29,y)

# %%
import matplotlib.pyplot as plt
x30=d['une_literacy']
y=d['life_expect']
plt.plot(x30,y)

# %%
import matplotlib.pyplot as plt
x31=d['une_school']
y=d['life_expect']
plt.plot(x31,y)
